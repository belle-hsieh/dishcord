# %%
import numpy as np
import pandas as pd

# %%
michelin_restaurants_path = '/Users/grace/Downloads/michelin_my_maps.csv'
yelp_restaurants_path = '/Users/grace/Downloads/Yelp JSON/yelp_dataset/yelp_academic_dataset_business.json'

# %%
michelin = pd.read_csv(michelin_restaurants_path)
yelp = pd.read_json(yelp_restaurants_path)

# %%
michelin.head()

# %%
yelp.head()
